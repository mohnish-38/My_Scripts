# %%
import seaborn as sn
import matplotlib.pyplot as mlpt

# %%
df=sn.load_dataset("tips")

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df.corr()
sn.heatmap(df.corr())

# %%
df.dtypes
# Out:
# total_bill     float64
# tip            float64
# sex           category
# smoker        category
# day           category
# time          category
# size             int64
# dtype: object

# %%
sn.choose_dark_palette(input='husl', as_cmap=False)
# Out:
# interactive(children=(IntSlider(value=179, description='h', max=359), IntSlider(value=49, description='s', max…
# [array([0.13333333, 0.13333333, 0.13333333, 1.        ]),
#  array([0.15505626, 0.17201694, 0.16963164, 1.        ]),
#  array([0.17677918, 0.21070054, 0.20592994, 1.        ]),
#  array([0.19927793, 0.2507657 , 0.24352462, 1.        ]),
#  array([0.22100085, 0.2894493 , 0.27982292, 1.        ]),
#  array([0.2434996 , 0.32951446, 0.31741759, 1.        ]),
#  array([0.26522252, 0.36819806, 0.3537159 , 1.        ]),
#  array([0.28772127, 0.40826322, 0.39131057, 1.        ]),
#  array([0.30944419, 0.44694683, 0.42760888, 1.        ]),
#  array([0.33116712, 0.48563043, 0.46390718, 1.        ])]

# %%
a=sn.choose_cubehelix_palette(as_cmap=False)
# Out:
# interactive(children=(IntSlider(value=9, description='n_colors', max=16, min=2), FloatSlider(value=0.0, descri…

# %%
sn.jointplot("tip","total_bill",data=df,kind='reg')

# %%
sn.jointplot("tip","total_bill",data=df,kind='hex')

# %%
sn.jointplot("tip","total_bill",data=df,kind='kde')

# %%
sn.jointplot("tip","total_bill",data=df,kind='reside')

# %%
sn.jointplot("tip","total_bill",data=df,kind='scatter')

# %%
sn.pairplot(df)

# %%
sn.pairplot(df,hue="size")
# Out:
# C:\Users\CLASSY\Anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py:487: RuntimeWarning: invalid value encountered in true_divide
#   binned = fast_linbin(X, a, b, gridsize) / (delta * nobs)
# C:\Users\CLASSY\Anaconda3\lib\site-packages\statsmodels\nonparametric\kdetools.py:34: RuntimeWarning: invalid value encountered in double_scalars
#   FAC1 = 2*(np.pi*bw/RANGE)**2

# %%
sn.countplot("sex",data=df)

# %%
sn.boxplot(x="sex",y="total_bill",data=df)

# %%
sn.boxenplot(x="sex",y="total_bill",data=df)

# %%
sn.barplot(x="sex",y="total_bill",data=df)

# %%
sn.violinplot(x="sex",y="total_bill",data=df)

# %%
sn.countplot(x="sex",data=df)

# %%
sn.countplot(x="day",data=df,orient='H')

# %%
iris=sn.load_dataset("iris")

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa
